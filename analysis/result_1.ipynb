# %%
import glob
import pandas as pd

# %%
data_default = []
data_train = []
data_fourier = []
for file in glob.glob(f"../evaluation/fourier/n_020_budget_0500_??.csv"):
    df = pd.read_csv(file, index_col=0).transpose()
    data_default.append(df["Default"])
    data_train.append(df["Train"])
    data_fourier.append(df["Fourier"])
data_all = [pd.DataFrame(data_default).mean(),
            pd.DataFrame(data_train).mean(),
            pd.DataFrame(data_fourier).mean()]
df = pd.DataFrame(data_all, index=["Default", "Train", "Fourier"])
df
# Out:
#          cbench-automotive-bitcount:number-0001:  \
# Default                                 0.067156
# Train                                   0.054919
# Fourier                                 0.059756
#
#          cbench-automotive-qsort1:cdataset-qsort-0001:  \
# Default                                       0.019549
# Train                                         0.018897
# Fourier                                       0.019348
#
#          cbench-automotive-qsort1:cdataset-qsort-0005:  \
# Default                                       0.012255
# Train                                         0.011775
# Fourier                                       0.012098
#
#          cbench-automotive-qsort1:cdataset-qsort-0009:  \
# Default                                       0.017624
# Train                                         0.016968
# Fourier                                       0.017348
#
#          cbench-automotive-qsort1:cdataset-qsort-0013:  \
# ...

# %%
df_train = pd.DataFrame(data_train).reset_index()
df_fourier = pd.DataFrame(data_fourier).reset_index()
(df_fourier < df_train).sum() / len(df_train.index)
# Out:
# index                                               1.00
# cbench-automotive-bitcount:number-0001:             0.05
# cbench-automotive-qsort1:cdataset-qsort-0001:       0.00
# cbench-automotive-qsort1:cdataset-qsort-0005:       0.00
# cbench-automotive-qsort1:cdataset-qsort-0009:       0.00
# cbench-automotive-qsort1:cdataset-qsort-0013:       0.00
# cbench-automotive-qsort1:cdataset-qsort-0017:       0.00
# cbench-automotive-qsort1:cdataset-qsort-0020:       0.00
# cbench-automotive-susan:image-pgm-0001:corners      0.00
# cbench-automotive-susan:image-pgm-0005:corners      0.00
# cbench-automotive-susan:image-pgm-0009:corners      0.00
# cbench-automotive-susan:image-pgm-0013:corners      0.00
# cbench-automotive-susan:image-pgm-0017:corners      0.00
# cbench-automotive-susan:image-pgm-0020:corners      0.00
# cbench-automotive-susan:image-pgm-0001:edges        0.05
# cbench-automotive-susan:image-pgm-0005:edges        0.15
# ...
