# %%
import glob
import pandas as pd

# %%
alphas = {
    "1e-1": "fourier_1e-01",
    "1e-2": "fourier",
    "1e-3": "fourier_1e-03",
    "1e-4": "fourier_1e-04",
    "1e-5": "fourier_1e-05"}
data_validate_scores = []
data_speedup = []
for alpha, path in alphas.items():
    validate_scores = []
    for file in glob.glob(f"../evaluation/{path}/n_020_budget_0500_??_validate_score.csv"):
        df = pd.read_csv(file, index_col=0).transpose()
        validate_scores.append(df["Fourier"])
    assert validate_scores
    df = pd.DataFrame(validate_scores)
    data_validate_scores.append(df.mean())

    speedup = []
    for file in glob.glob(f"../evaluation/{path}/n_020_budget_0500_??.csv"):
        df = pd.read_csv(file, index_col=0).transpose()
        speedup.append(df["Train"] / df["Fourier"])
    assert speedup
    df = pd.DataFrame(speedup)
    data_speedup.append(df.mean())
validate_scores = pd.DataFrame(data_validate_scores, index=alphas.keys()).transpose()
speedup = pd.DataFrame(data_speedup, index=alphas.keys()).transpose()

# %%
def shorten_program_name(s: str):
    prefix = "cbench-"
    if not s.startswith(prefix):
        raise ValueError("Not a cbench program")
    return s[len(prefix):]


validate_scores.rename(index=shorten_program_name, inplace=True)
speedup.rename(index=shorten_program_name, inplace=True)

# %%
validate_scores
# Out:
#                                                       1e-1      1e-2  \
# cbench-automotive-bitcount:number-0001:           0.620514  0.774045
# cbench-automotive-qsort1:cdataset-qsort-0001:     0.760326  0.879735
# cbench-automotive-qsort1:cdataset-qsort-0005:     0.759980  0.879779
# cbench-automotive-qsort1:cdataset-qsort-0009:     0.757667  0.879309
# cbench-automotive-qsort1:cdataset-qsort-0013:     0.760561  0.880081
# cbench-automotive-qsort1:cdataset-qsort-0017:     0.759323  0.879923
# cbench-automotive-qsort1:cdataset-qsort-0020:     0.760189  0.880827
# cbench-automotive-susan:image-pgm-0001:corners    0.750249  0.800191
# cbench-automotive-susan:image-pgm-0005:corners    0.814545  0.851204
# cbench-automotive-susan:image-pgm-0009:corners    0.814507  0.853161
# cbench-automotive-susan:image-pgm-0013:corners    0.262847  0.386247
# cbench-automotive-susan:image-pgm-0017:corners    0.650981  0.718061
# cbench-automotive-susan:image-pgm-0020:corners    0.702003  0.758898
# cbench-automotive-susan:image-pgm-0001:edges      0.852058  0.933714
# cbench-automotive-susan:image-pgm-0005:edges      0.836085  0.920749
# cbench-automotive-susan:image-pgm-0009:edges      0.777011  0.844665
# cbench-automotive-susan:image-pgm-0013:edges      0.891277  0.976331
# cbench-automotive-susan:image-pgm-0017:edges      0.871640  0.956968
# cbench-automotive-susan:image-pgm-0020:edges      0.847309  0.922831
# cbench-automotive-susan:image-pgm-0001:smoothing  0.423048  0.465012
# cbench-automotive-susan:image-pgm-0005:smoothing  0.423079  0.464698
# cbench-automotive-susan:image-pgm-0009:smoothing  0.422703  0.464639
# cbench-automotive-susan:image-pgm-0013:smoothing  0.422384  0.464603
# cbench-automotive-susan:image-pgm-0017:smoothing  0.422716  0.463183
# cbench-automotive-susan:image-pgm-0020:smoothing  0.422827  0.464365
# cbench-network-dijkstra:cdataset-dijkstra-0001:   0.610569  0.737255
# cbench-network-dijkstra:cdataset-dijkstra-0005:   0.639336  0.835728
# cbench-network-dijkstra:cdataset-dijkstra-0009:   0.638842  0.834319
# cbench-network-dijkstra:cdataset-dijkstra-0013:   0.639747  0.835549
# cbench-network-patricia:cdataset-patricia-0001:   0.970276  0.986913
# cbench-network-patricia:cdataset-patricia-0005:   0.933068  0.968421
# cbench-network-patricia:cdataset-patricia-0009:   0.836619  0.874054
# cbench-network-patricia:cdataset-patricia-0013:   0.753509  0.780898
# cbench-network-patricia:cdataset-patricia-0017:   0.713459  0.739210
# cbench-network-patricia:cdataset-patricia-0020:   0.725706  0.750860
# cbench-telecom-adpcm-c:pcm-0001:                  0.373095  0.628216
# cbench-telecom-adpcm-c:pcm-0005:                  0.338782  0.570180
# cbench-telecom-adpcm-c:pcm-0009:                  0.368587  0.625902
# cbench-telecom-adpcm-c:pcm-0013:                  0.380146  0.636447
# cbench-telecom-adpcm-c:pcm-0017:                  0.384704  0.626852
# cbench-telecom-adpcm-c:pcm-0020:                  0.347673  0.593540
# cbench-telecom-adpcm-d:adpcm-0001:                0.885866  0.966113
# cbench-telecom-adpcm-d:adpcm-0005:                0.886003  0.965624
# cbench-telecom-adpcm-d:adpcm-0009:                0.887555  0.967064
# cbench-telecom-adpcm-d:adpcm-0013:                0.884992  0.963471
# cbench-telecom-adpcm-d:adpcm-0017:                0.884673  0.965360
# cbench-telecom-adpcm-d:adpcm-0020:                0.880347  0.956932
# cbench-telecom-crc32:pcm-0001:                    0.628562  0.889571
# cbench-telecom-crc32:pcm-0005:                    0.636707  0.892616
# cbench-telecom-crc32:pcm-0009:                    0.637408  0.890923
# cbench-telecom-crc32:pcm-0013:                    0.641990  0.900966
# cbench-telecom-crc32:pcm-0017:                    0.641688  0.901205
# cbench-telecom-crc32:pcm-0020:                    0.642074  0.901545
# cbench-telecom-gsm:au-0001:                       0.733086  0.938161
# cbench-telecom-gsm:au-0005:                       0.740851  0.939973
# cbench-telecom-gsm:au-0009:                       0.740105  0.940433
# cbench-telecom-gsm:au-0013:                       0.745284  0.936704
# cbench-telecom-gsm:au-0017:                       0.739875  0.939572
# cbench-telecom-gsm:au-0020:                       0.739686  0.939928
#
#                                                       1e-3      1e-4      1e-5
# cbench-automotive-bitcount:number-0001:           0.658936  0.524084  0.431913
# cbench-automotive-qsort1:cdataset-qsort-0001:     0.825186  0.740111  0.717315
# cbench-automotive-qsort1:cdataset-qsort-0005:     0.831175  0.755726  0.709858
# cbench-automotive-qsort1:cdataset-qsort-0009:     0.820966  0.731804  0.700016
# cbench-automotive-qsort1:cdataset-qsort-0013:     0.824720  0.736682  0.698761
# cbench-automotive-qsort1:cdataset-qsort-0017:     0.829560  0.743899  0.711197
# cbench-automotive-qsort1:cdataset-qsort-0020:     0.825480  0.742232  0.696451
# cbench-automotive-susan:image-pgm-0001:corners    0.687383  0.528806  0.465466
# cbench-automotive-susan:image-pgm-0005:corners    0.766785  0.666613  0.602877
# cbench-automotive-susan:image-pgm-0009:corners    0.768550  0.660992  0.609886
# cbench-automotive-susan:image-pgm-0013:corners   -0.066038 -0.482628 -0.580365
# cbench-automotive-susan:image-pgm-0017:corners    0.538836  0.335365  0.250486
# cbench-automotive-susan:image-pgm-0020:corners    0.615120  0.406798  0.366027
# cbench-automotive-susan:image-pgm-0001:edges      0.904185  0.851832  0.831545
# cbench-automotive-susan:image-pgm-0005:edges      0.885497  0.824290  0.802704
# cbench-automotive-susan:image-pgm-0009:edges      0.748751  0.602236  0.568509
# cbench-automotive-susan:image-pgm-0013:edges      0.975762  0.959363  0.951391
# cbench-automotive-susan:image-pgm-0017:edges      0.940097  0.908316  0.896433
# cbench-automotive-susan:image-pgm-0020:edges      0.886292  0.827996  0.798687
# cbench-automotive-susan:image-pgm-0001:smoothing  0.094658 -0.211841 -0.380752
# cbench-automotive-susan:image-pgm-0005:smoothing  0.162197 -0.270095 -0.362974
# cbench-automotive-susan:image-pgm-0009:smoothing  0.129745 -0.260665 -0.360518
# cbench-automotive-susan:image-pgm-0013:smoothing  0.092696 -0.239588 -0.384135
# cbench-automotive-susan:image-pgm-0017:smoothing  0.143250 -0.218135 -0.382999
# cbench-automotive-susan:image-pgm-0020:smoothing  0.130277 -0.243489 -0.350774
# cbench-network-dijkstra:cdataset-dijkstra-0001:   0.624190  0.463604  0.406168
# cbench-network-dijkstra:cdataset-dijkstra-0005:   0.808061  0.717089  0.652574
# cbench-network-dijkstra:cdataset-dijkstra-0009:   0.803050  0.717804  0.649985
# cbench-network-dijkstra:cdataset-dijkstra-0013:   0.804555  0.737897  0.652155
# cbench-network-patricia:cdataset-patricia-0001:   0.983392  0.972261  0.962476
# cbench-network-patricia:cdataset-patricia-0005:   0.955837  0.927338  0.915519
# cbench-network-patricia:cdataset-patricia-0009:   0.792259  0.693664  0.645788
# cbench-network-patricia:cdataset-patricia-0013:   0.638056  0.469762  0.390204
# cbench-network-patricia:cdataset-patricia-0017:   0.561376  0.356604  0.282123
# cbench-network-patricia:cdataset-patricia-0020:   0.573544  0.375570  0.310986
# cbench-telecom-adpcm-c:pcm-0001:                  0.420434  0.205716  0.127015
# cbench-telecom-adpcm-c:pcm-0005:                  0.318555  0.123993  0.006409
# cbench-telecom-adpcm-c:pcm-0009:                  0.422731  0.187747  0.079336
# cbench-telecom-adpcm-c:pcm-0013:                  0.418437  0.212881  0.131922
# cbench-telecom-adpcm-c:pcm-0017:                  0.419230  0.170247  0.074393
# cbench-telecom-adpcm-c:pcm-0020:                  0.346019  0.092152  0.025677
# cbench-telecom-adpcm-d:adpcm-0001:                0.957891  0.932230  0.932681
# cbench-telecom-adpcm-d:adpcm-0005:                0.955243  0.928155  0.930676
# cbench-telecom-adpcm-d:adpcm-0009:                0.957789  0.931146  0.931920
# cbench-telecom-adpcm-d:adpcm-0013:                0.944505  0.914934  0.915926
# cbench-telecom-adpcm-d:adpcm-0017:                0.953334  0.931321  0.924134
# cbench-telecom-adpcm-d:adpcm-0020:                0.940752  0.897515  0.913827
# cbench-telecom-crc32:pcm-0001:                    0.910961  0.811931  0.835230
# cbench-telecom-crc32:pcm-0005:                    0.896259  0.837169  0.826649
# cbench-telecom-crc32:pcm-0009:                    0.921445  0.840723  0.834382
# cbench-telecom-crc32:pcm-0013:                    0.930301  0.879631  0.867512
# cbench-telecom-crc32:pcm-0017:                    0.937788  0.882345  0.877957
# cbench-telecom-crc32:pcm-0020:                    0.943764  0.883637  0.887144
# cbench-telecom-gsm:au-0001:                       0.929493  0.898145  0.878028
# cbench-telecom-gsm:au-0005:                       0.930116  0.899399  0.877300
# cbench-telecom-gsm:au-0009:                       0.929037  0.896220  0.879801
# cbench-telecom-gsm:au-0013:                       0.924357  0.883235  0.866402
# cbench-telecom-gsm:au-0017:                       0.929927  0.898412  0.878436
# cbench-telecom-gsm:au-0020:                       0.932153  0.899833  0.879105

# %%
validate_scores.mean()
# Out:
# 1e-1    0.678249
# 1e-2    0.806504
# 1e-3    0.707371
# 1e-4    0.577814
# 1e-5    0.529777
# dtype: float64

# %%
validate_scores.transpose().idxmax().value_counts()
# Out:
# 1e-2    53
# 1e-3     6
# dtype: int64

# %%
# Speedup of the learned flags over the best flags from the training data
speedup
# Out:
#                                                       1e-1      1e-2  \
# cbench-automotive-bitcount:number-0001:           0.962304  0.925055
# cbench-automotive-qsort1:cdataset-qsort-0001:     0.959824  0.976752
# cbench-automotive-qsort1:cdataset-qsort-0005:     0.961741  0.973384
# cbench-automotive-qsort1:cdataset-qsort-0009:     0.961565  0.978151
# cbench-automotive-qsort1:cdataset-qsort-0013:     0.964044  0.978252
# cbench-automotive-qsort1:cdataset-qsort-0017:     0.963340  0.974605
# cbench-automotive-qsort1:cdataset-qsort-0020:     0.961002  0.976333
# cbench-automotive-susan:image-pgm-0001:corners    0.966543  0.976827
# cbench-automotive-susan:image-pgm-0005:corners    0.970127  0.972444
# cbench-automotive-susan:image-pgm-0009:corners    0.976335  0.978938
# cbench-automotive-susan:image-pgm-0013:corners    0.974628  0.981256
# cbench-automotive-susan:image-pgm-0017:corners    0.970145  0.984220
# cbench-automotive-susan:image-pgm-0020:corners    0.971685  0.979644
# cbench-automotive-susan:image-pgm-0001:edges      0.979642  0.992827
# cbench-automotive-susan:image-pgm-0005:edges      0.973514  0.991754
# cbench-automotive-susan:image-pgm-0009:edges      0.970636  0.983161
# cbench-automotive-susan:image-pgm-0013:edges      0.986921  0.998754
# cbench-automotive-susan:image-pgm-0017:edges      0.982783  0.993981
# cbench-automotive-susan:image-pgm-0020:edges      0.980926  0.993645
# cbench-automotive-susan:image-pgm-0001:smoothing  0.928310  0.908744
# cbench-automotive-susan:image-pgm-0005:smoothing  0.931247  0.912208
# cbench-automotive-susan:image-pgm-0009:smoothing  0.931701  0.919173
# cbench-automotive-susan:image-pgm-0013:smoothing  0.926816  0.908898
# cbench-automotive-susan:image-pgm-0017:smoothing  0.928963  0.913008
# cbench-automotive-susan:image-pgm-0020:smoothing  0.930362  0.911022
# cbench-network-dijkstra:cdataset-dijkstra-0001:   0.974464  0.988654
# cbench-network-dijkstra:cdataset-dijkstra-0005:   0.917499  0.968637
# cbench-network-dijkstra:cdataset-dijkstra-0009:   0.926852  0.969307
# cbench-network-dijkstra:cdataset-dijkstra-0013:   0.937297  0.971745
# cbench-network-patricia:cdataset-patricia-0001:   0.902825  0.943013
# cbench-network-patricia:cdataset-patricia-0005:   0.960702  0.975944
# cbench-network-patricia:cdataset-patricia-0009:   0.973315  0.984712
# cbench-network-patricia:cdataset-patricia-0013:   0.978203  0.981261
# cbench-network-patricia:cdataset-patricia-0017:   0.979680  0.984369
# cbench-network-patricia:cdataset-patricia-0020:   0.981660  0.988598
# cbench-telecom-adpcm-c:pcm-0001:                  0.995743  0.976420
# cbench-telecom-adpcm-c:pcm-0005:                  0.989646  0.975646
# cbench-telecom-adpcm-c:pcm-0009:                  0.997353  0.980163
# cbench-telecom-adpcm-c:pcm-0013:                  0.997037  0.982932
# cbench-telecom-adpcm-c:pcm-0017:                  0.996913  0.973652
# cbench-telecom-adpcm-c:pcm-0020:                  0.987377  0.961630
# cbench-telecom-adpcm-d:adpcm-0001:                0.997893  0.996823
# cbench-telecom-adpcm-d:adpcm-0005:                0.998135  0.996224
# cbench-telecom-adpcm-d:adpcm-0009:                0.998203  0.997753
# cbench-telecom-adpcm-d:adpcm-0013:                0.998216  0.997661
# cbench-telecom-adpcm-d:adpcm-0017:                0.998418  0.997034
# cbench-telecom-adpcm-d:adpcm-0020:                0.996706  0.996955
# cbench-telecom-crc32:pcm-0001:                    0.933012  0.864709
# cbench-telecom-crc32:pcm-0005:                    0.934331  0.890835
# cbench-telecom-crc32:pcm-0009:                    0.933151  0.826999
# cbench-telecom-crc32:pcm-0013:                    0.935523  0.830459
# cbench-telecom-crc32:pcm-0017:                    0.934804  0.868307
# cbench-telecom-crc32:pcm-0020:                    0.936242  0.887197
# cbench-telecom-gsm:au-0001:                       0.959359  0.990302
# cbench-telecom-gsm:au-0005:                       0.965038  0.985843
# cbench-telecom-gsm:au-0009:                       0.961507  0.990260
# cbench-telecom-gsm:au-0013:                       0.962283  0.983786
# cbench-telecom-gsm:au-0017:                       0.958200  0.988661
# cbench-telecom-gsm:au-0020:                       0.969943  0.981084
#
#                                                       1e-3      1e-4      1e-5
# cbench-automotive-bitcount:number-0001:           0.936308  0.930180  0.930547
# cbench-automotive-qsort1:cdataset-qsort-0001:     0.983054  0.982844  0.975843
# cbench-automotive-qsort1:cdataset-qsort-0005:     0.978402  0.975534  0.976379
# cbench-automotive-qsort1:cdataset-qsort-0009:     0.979237  0.974386  0.973798
# cbench-automotive-qsort1:cdataset-qsort-0013:     0.976651  0.977749  0.976663
# cbench-automotive-qsort1:cdataset-qsort-0017:     0.972192  0.970844  0.978106
# cbench-automotive-qsort1:cdataset-qsort-0020:     0.983021  0.977364  0.977248
# cbench-automotive-susan:image-pgm-0001:corners    0.976781  0.981030  0.972212
# cbench-automotive-susan:image-pgm-0005:corners    0.977212  0.975249  0.976274
# cbench-automotive-susan:image-pgm-0009:corners    0.974951  0.977426  0.974757
# cbench-automotive-susan:image-pgm-0013:corners    0.977831  0.976106  0.977501
# cbench-automotive-susan:image-pgm-0017:corners    0.986646  0.979732  0.974645
# cbench-automotive-susan:image-pgm-0020:corners    0.980805  0.977380  0.977486
# cbench-automotive-susan:image-pgm-0001:edges      0.993681  0.987347  0.984280
# cbench-automotive-susan:image-pgm-0005:edges      0.985560  0.990422  0.989956
# cbench-automotive-susan:image-pgm-0009:edges      0.985715  0.974228  0.979878
# cbench-automotive-susan:image-pgm-0013:edges      0.996482  0.991130  0.992176
# cbench-automotive-susan:image-pgm-0017:edges      0.992592  0.992101  0.989216
# cbench-automotive-susan:image-pgm-0020:edges      0.991719  0.988900  0.985267
# cbench-automotive-susan:image-pgm-0001:smoothing  0.920648  0.897743  0.878112
# cbench-automotive-susan:image-pgm-0005:smoothing  0.904554  0.909049  0.911737
# cbench-automotive-susan:image-pgm-0009:smoothing  0.889734  0.915182  0.887069
# cbench-automotive-susan:image-pgm-0013:smoothing  0.894621  0.913512  0.913900
# cbench-automotive-susan:image-pgm-0017:smoothing  0.904860  0.908214  0.901141
# cbench-automotive-susan:image-pgm-0020:smoothing  0.897284  0.935272  0.888925
# cbench-network-dijkstra:cdataset-dijkstra-0001:   0.965568  0.984051  0.950180
# cbench-network-dijkstra:cdataset-dijkstra-0005:   0.967756  0.963958  0.965458
# cbench-network-dijkstra:cdataset-dijkstra-0009:   0.970936  0.959957  0.951048
# cbench-network-dijkstra:cdataset-dijkstra-0013:   0.950365  0.969663  0.953983
# cbench-network-patricia:cdataset-patricia-0001:   0.932388  0.921321  0.936180
# cbench-network-patricia:cdataset-patricia-0005:   0.976958  0.971623  0.972965
# cbench-network-patricia:cdataset-patricia-0009:   0.975336  0.976544  0.974922
# cbench-network-patricia:cdataset-patricia-0013:   0.971946  0.979119  0.977751
# cbench-network-patricia:cdataset-patricia-0017:   0.984385  0.977251  0.974952
# cbench-network-patricia:cdataset-patricia-0020:   0.977533  0.979322  0.980186
# cbench-telecom-adpcm-c:pcm-0001:                  0.974042  0.982040  0.980159
# cbench-telecom-adpcm-c:pcm-0005:                  0.984530  0.988468  0.975666
# cbench-telecom-adpcm-c:pcm-0009:                  0.977020  0.978510  0.982778
# cbench-telecom-adpcm-c:pcm-0013:                  0.975594  0.980010  0.977884
# cbench-telecom-adpcm-c:pcm-0017:                  0.970036  0.981123  0.975242
# cbench-telecom-adpcm-c:pcm-0020:                  0.963038  0.966378  0.963165
# cbench-telecom-adpcm-d:adpcm-0001:                0.995329  0.993856  0.994627
# cbench-telecom-adpcm-d:adpcm-0005:                0.997238  0.996937  0.994732
# cbench-telecom-adpcm-d:adpcm-0009:                0.995488  0.994105  0.995347
# cbench-telecom-adpcm-d:adpcm-0013:                0.997270  0.993610  0.995030
# cbench-telecom-adpcm-d:adpcm-0017:                0.998907  0.995777  0.997594
# cbench-telecom-adpcm-d:adpcm-0020:                0.995003  0.991021  0.995530
# cbench-telecom-crc32:pcm-0001:                    0.927850  0.958818  0.955110
# cbench-telecom-crc32:pcm-0005:                    0.930481  0.928163  0.926374
# cbench-telecom-crc32:pcm-0009:                    0.932758  0.922912  0.903286
# cbench-telecom-crc32:pcm-0013:                    0.937423  0.937696  0.917146
# cbench-telecom-crc32:pcm-0017:                    0.964804  0.959905  0.929227
# cbench-telecom-crc32:pcm-0020:                    0.967652  0.963082  0.932490
# cbench-telecom-gsm:au-0001:                       0.985899  0.992010  0.989459
# cbench-telecom-gsm:au-0005:                       0.986748  0.985712  0.985134
# cbench-telecom-gsm:au-0009:                       0.989383  0.987118  0.980013
# cbench-telecom-gsm:au-0013:                       0.982821  0.983103  0.988132
# cbench-telecom-gsm:au-0017:                       0.983346  0.991123  0.987087
# cbench-telecom-gsm:au-0020:                       0.989639  0.989862  0.983487

# %%
speedup.mean()
# Out:
# 1e-1    0.964112
# 1e-2    0.962044
# 1e-3    0.968068
# 1e-4    0.969205
# 1e-5    0.964160
# dtype: float64

# %%
# How often is this alpha value the worst
speedup.transpose().idxmin().value_counts()
# Out:
# 1e-1    29
# 1e-2     9
# 1e-5     8
# 1e-3     8
# 1e-4     5
# dtype: int64

# %%
# How often is this alpha values the best
speedup.transpose().idxmax().value_counts()
# Out:
# 1e-1    18
# 1e-3    16
# 1e-2    16
# 1e-4     7
# 1e-5     2
# dtype: int64
