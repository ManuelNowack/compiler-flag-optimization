# %%
import glob
import pandas as pd

# %%
alphas = {
    "1e-1": "fourier_1e-01",
    "1e-2": "fourier",
    "1e-3": "fourier_1e-03",
    "1e-4": "fourier_1e-04",
    "1e-5": "fourier_1e-05"}
data_validate_scores = []
data_speedup = []
for alpha, path in alphas.items():
    validate_scores = []
    for file in glob.glob(f"../evaluation/{path}/n_020_budget_0500_??_validate_score.csv"):
        df = pd.read_csv(file, index_col=0).transpose()
        validate_scores.append(df["Fourier"])
    assert validate_scores
    df = pd.DataFrame(validate_scores)
    data_validate_scores.append(df.mean())

    speedup = []
    for file in glob.glob(f"../evaluation/{path}/n_020_budget_0500_??.csv"):
        df = pd.read_csv(file, index_col=0).transpose()
        speedup.append(df["Train"] / df["Fourier"])
    assert speedup
    df = pd.DataFrame(speedup)
    data_speedup.append(df.mean())
validate_scores = pd.DataFrame(data_validate_scores, index=alphas.keys())
speedup = pd.DataFrame(data_speedup, index=alphas.keys())

# %%
validate_scores.to_csv("csv/n_20_validate_scores.csv")
validate_scores
# Out:
#       cbench-automotive-bitcount:number-0001:  \
# 1e-1                                 0.620514
# 1e-2                                 0.774045
# 1e-3                                 0.658936
# 1e-4                                 0.524084
# 1e-5                                 0.431913
#
#       cbench-automotive-qsort1:cdataset-qsort-0001:  \
# 1e-1                                       0.760326
# 1e-2                                       0.879735
# 1e-3                                       0.825186
# 1e-4                                       0.740111
# 1e-5                                       0.717315
#
#       cbench-automotive-qsort1:cdataset-qsort-0005:  \
# 1e-1                                       0.759980
# 1e-2                                       0.879779
# 1e-3                                       0.831175
# 1e-4                                       0.755726
# 1e-5                                       0.709858
#
#       cbench-automotive-qsort1:cdataset-qsort-0009:  \
# 1e-1                                       0.757667
# 1e-2                                       0.879309
# 1e-3                                       0.820966
# 1e-4                                       0.731804
# 1e-5                                       0.700016
#
#       cbench-automotive-qsort1:cdataset-qsort-0013:  \
# 1e-1                                       0.760561
# 1e-2                                       0.880081
# 1e-3                                       0.824720
# 1e-4                                       0.736682
# 1e-5                                       0.698761
#
#       cbench-automotive-qsort1:cdataset-qsort-0017:  \
# 1e-1                                       0.759323
# 1e-2                                       0.879923
# 1e-3                                       0.829560
# 1e-4                                       0.743899
# 1e-5                                       0.711197
#
#       cbench-automotive-qsort1:cdataset-qsort-0020:  \
# 1e-1                                       0.760189
# 1e-2                                       0.880827
# 1e-3                                       0.825480
# 1e-4                                       0.742232
# 1e-5                                       0.696451
#
#       cbench-automotive-susan:image-pgm-0001:corners  \
# 1e-1                                        0.750249
# 1e-2                                        0.800191
# 1e-3                                        0.687383
# 1e-4                                        0.528806
# 1e-5                                        0.465466
#
#       cbench-automotive-susan:image-pgm-0005:corners  \
# 1e-1                                        0.814545
# 1e-2                                        0.851204
# 1e-3                                        0.766785
# 1e-4                                        0.666613
# 1e-5                                        0.602877
#
#       cbench-automotive-susan:image-pgm-0009:corners  ...  \
# 1e-1                                        0.814507  ...
# 1e-2                                        0.853161  ...
# 1e-3                                        0.768550  ...
# 1e-4                                        0.660992  ...
# 1e-5                                        0.609886  ...
#
#       cbench-telecom-crc32:pcm-0009:  cbench-telecom-crc32:pcm-0013:  \
# 1e-1                        0.637408                        0.641990
# 1e-2                        0.890923                        0.900966
# 1e-3                        0.921445                        0.930301
# 1e-4                        0.840723                        0.879631
# 1e-5                        0.834382                        0.867512
#
#       cbench-telecom-crc32:pcm-0017:  cbench-telecom-crc32:pcm-0020:  \
# 1e-1                        0.641688                        0.642074
# 1e-2                        0.901205                        0.901545
# 1e-3                        0.937788                        0.943764
# 1e-4                        0.882345                        0.883637
# 1e-5                        0.877957                        0.887144
#
#       cbench-telecom-gsm:au-0001:  cbench-telecom-gsm:au-0005:  \
# 1e-1                     0.733086                     0.740851
# 1e-2                     0.938161                     0.939973
# 1e-3                     0.929493                     0.930116
# 1e-4                     0.898145                     0.899399
# 1e-5                     0.878028                     0.877300
#
#       cbench-telecom-gsm:au-0009:  cbench-telecom-gsm:au-0013:  \
# 1e-1                     0.740105                     0.745284
# 1e-2                     0.940433                     0.936704
# 1e-3                     0.929037                     0.924357
# 1e-4                     0.896220                     0.883235
# 1e-5                     0.879801                     0.866402
#
#       cbench-telecom-gsm:au-0017:  cbench-telecom-gsm:au-0020:
# 1e-1                     0.739875                     0.739686
# 1e-2                     0.939572                     0.939928
# 1e-3                     0.929927                     0.932153
# 1e-4                     0.898412                     0.899833
# 1e-5                     0.878436                     0.879105
#
# [5 rows x 59 columns]

# %%
validate_scores.mean(1)
# Out:
# 1e-1    0.678249
# 1e-2    0.806504
# 1e-3    0.707371
# 1e-4    0.577814
# 1e-5    0.529777
# dtype: float64

# %%
# Speedup of the learned flags over the best flags from the training data
speedup.to_csv("csv/n_20_validate_scores_speedup.csv")
speedup
# Out:
#       cbench-automotive-bitcount:number-0001:  \
# 1e-1                                 0.962304
# 1e-2                                 0.925055
# 1e-3                                 0.936308
# 1e-4                                 0.930180
# 1e-5                                 0.930547
#
#       cbench-automotive-qsort1:cdataset-qsort-0001:  \
# 1e-1                                       0.959824
# 1e-2                                       0.976752
# 1e-3                                       0.983054
# 1e-4                                       0.982844
# 1e-5                                       0.975843
#
#       cbench-automotive-qsort1:cdataset-qsort-0005:  \
# 1e-1                                       0.961741
# 1e-2                                       0.973384
# 1e-3                                       0.978402
# 1e-4                                       0.975534
# 1e-5                                       0.976379
#
#       cbench-automotive-qsort1:cdataset-qsort-0009:  \
# 1e-1                                       0.961565
# 1e-2                                       0.978151
# 1e-3                                       0.979237
# 1e-4                                       0.974386
# 1e-5                                       0.973798
#
#       cbench-automotive-qsort1:cdataset-qsort-0013:  \
# 1e-1                                       0.964044
# 1e-2                                       0.978252
# 1e-3                                       0.976651
# 1e-4                                       0.977749
# 1e-5                                       0.976663
#
#       cbench-automotive-qsort1:cdataset-qsort-0017:  \
# 1e-1                                       0.963340
# 1e-2                                       0.974605
# 1e-3                                       0.972192
# 1e-4                                       0.970844
# 1e-5                                       0.978106
#
#       cbench-automotive-qsort1:cdataset-qsort-0020:  \
# 1e-1                                       0.961002
# 1e-2                                       0.976333
# 1e-3                                       0.983021
# 1e-4                                       0.977364
# 1e-5                                       0.977248
#
#       cbench-automotive-susan:image-pgm-0001:corners  \
# 1e-1                                        0.966543
# 1e-2                                        0.976827
# 1e-3                                        0.976781
# 1e-4                                        0.981030
# 1e-5                                        0.972212
#
#       cbench-automotive-susan:image-pgm-0005:corners  \
# 1e-1                                        0.970127
# 1e-2                                        0.972444
# 1e-3                                        0.977212
# 1e-4                                        0.975249
# 1e-5                                        0.976274
#
#       cbench-automotive-susan:image-pgm-0009:corners  ...  \
# 1e-1                                        0.976335  ...
# 1e-2                                        0.978938  ...
# 1e-3                                        0.974951  ...
# 1e-4                                        0.977426  ...
# 1e-5                                        0.974757  ...
#
#       cbench-telecom-crc32:pcm-0009:  cbench-telecom-crc32:pcm-0013:  \
# 1e-1                        0.933151                        0.935523
# 1e-2                        0.826999                        0.830459
# 1e-3                        0.932758                        0.937423
# 1e-4                        0.922912                        0.937696
# 1e-5                        0.903286                        0.917146
#
#       cbench-telecom-crc32:pcm-0017:  cbench-telecom-crc32:pcm-0020:  \
# 1e-1                        0.934804                        0.936242
# 1e-2                        0.868307                        0.887197
# 1e-3                        0.964804                        0.967652
# 1e-4                        0.959905                        0.963082
# 1e-5                        0.929227                        0.932490
#
#       cbench-telecom-gsm:au-0001:  cbench-telecom-gsm:au-0005:  \
# 1e-1                     0.959359                     0.965038
# 1e-2                     0.990302                     0.985843
# 1e-3                     0.985899                     0.986748
# 1e-4                     0.992010                     0.985712
# 1e-5                     0.989459                     0.985134
#
#       cbench-telecom-gsm:au-0009:  cbench-telecom-gsm:au-0013:  \
# 1e-1                     0.961507                     0.962283
# 1e-2                     0.990260                     0.983786
# 1e-3                     0.989383                     0.982821
# 1e-4                     0.987118                     0.983103
# 1e-5                     0.980013                     0.988132
#
#       cbench-telecom-gsm:au-0017:  cbench-telecom-gsm:au-0020:
# 1e-1                     0.958200                     0.969943
# 1e-2                     0.988661                     0.981084
# 1e-3                     0.983346                     0.989639
# 1e-4                     0.991123                     0.989862
# 1e-5                     0.987087                     0.983487
#
# [5 rows x 59 columns]

# %%
speedup.mean(1)
# Out:
# 1e-1    0.964112
# 1e-2    0.962044
# 1e-3    0.968068
# 1e-4    0.969205
# 1e-5    0.964160
# dtype: float64
